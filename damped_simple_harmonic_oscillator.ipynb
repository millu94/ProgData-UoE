# %%
"""
   Damped harmonic oscillator
"""
import math
import matplotlib.pyplot as plt     # Import the plot package as plt

# determine whether damping is over-damped, critically damped, or under-damped,
# return x(t) ie displacement at time t
def evaluateDampedCondition(gamma, omega_0, t):
    a = 1
    if gamma > 2*omega_0:
        condition = "Over-Damped"
        p = math.sqrt((gamma**2)/4 - omega_0**2)
        b = gamma/(2*p)
        x = math.exp(-gamma*t/2)*(a*math.cosh(p*t) + b*math.sinh(p*t))
    
    elif gamma == 2*omega_0:
        condition = "Critically Damped"
        b = gamma/2
        x = math.exp(-gamma*t/2)*(a+b*t)

    else:
        condition = "Under-Damped"
        omega = math.sqrt(omega_0**2 - gamma**2/4)
        b = gamma/2*omega
        x = math.exp(-gamma*t/2)*(a*math.cos(omega*t) + b*math.sin(omega*t))
    
    return x, condition



def main():

    # Take in values for: damping coefficient per unit mass,
    # initial angular velocity,  plot points
    gamma = float(input("Damping Coefficient Per Unit Mass : "))
    print("Gamma : " + str(gamma))
    omega_0 = float(input("Initial Angular Velocity : "))
    print("Omega_0 : " + str(omega_0))
    plotPoints = int(input("Plot Points : "))
    print("Plot Points : " + str(plotPoints))

    t_data = []
    x_data = []
    
    maxTime = (5*math.pi)/omega_0
    print(str(maxTime))
    increment = maxTime/plotPoints

    for i in range(0, plotPoints): 
        t = increment*i
        x, condition = evaluateDampedCondition(gamma, omega_0, t)
        t_data.append(t)
        x_data.append(x)
        

    print(str(t_data))
    print(str(x_data))

    # Plot the trajectory 
    plt.plot(t_data,x_data,"b")          
    plt.title(f"{condition} Simple Harmonic Oscillator")
    # plt.title("Simple Harmonic Oscillator")
    
    plt.xlabel("Time")
    plt.ylabel("Amplitude")
    plt.show()                           

    

main()
# Out:
# Gamma : 2.0
# Omega_0 : 40.0
# Plot Points : 200
# 0.39269908169872414
# [0.0, 0.001963495408493621, 0.003926990816987242, 0.005890486225480863, 0.007853981633974483, 0.009817477042468103, 0.011780972450961725, 0.013744467859455347, 0.015707963267948967, 0.017671458676442587, 0.019634954084936207, 0.02159844949342983, 0.02356194490192345, 0.02552544031041707, 0.027488935718910694, 0.029452431127404314, 0.031415926535897934, 0.03337942194439156, 0.035342917352885174, 0.0373064127613788, 0.039269908169872414, 0.04123340357836604, 0.04319689898685966, 0.04516039439535328, 0.0471238898038469, 0.049087385212340524, 0.05105088062083414, 0.053014376029327764, 0.05497787143782139, 0.056941366846315004, 0.05890486225480863, 0.060868357663302244, 0.06283185307179587, 0.06479534848028949, 0.06675884388878311, 0.06872233929727672, 0.07068583470577035, 0.07264933011426397, 0.0746128255227576, 0.07657632093125122, 0.07853981633974483, 0.08050331174823845, 0.08246680715673207, 0.0844303025652257, 0.08639379797371932, 0.08835729338221295, 0.09032078879070655, 0.09228428419920018, 0.0942477796076938, 0.09621127501618743, 0.09817477042468105, 0.10013826583317466, 0.10210176124166828, 0.1040652566501619, 0.10602875205865553, 0.10799224746714915, 0.10995574287564278, 0.11191923828413639, 0.11388273369263001, 0.11584622910112363, 0.11780972450961726, 0.11977321991811088, 0.12173671532660449, 0.12370021073509811, 0.